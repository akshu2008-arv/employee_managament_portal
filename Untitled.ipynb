# %%
import pandas as pd

# %%
import os
# Out:
# 'C:\\Users\\dell\\OneDrive\\Desktop\\API_Project'

# %%
df
# Out:
#   employee_id         name              email department     salary  \
# 0      EMP001       string   user@example.com     string        1.0
# 1      EMP002  Priya Singh  priya@example.com         HR    65000.0
# 2      EMP003   Amit Kumar   amit@example.com    Finance    55000.0
# 3     aarav08        aarav      arv@gmail.com         HR  1000000.0
# 4      EMP007       aaRAV2    ttt@example.com    FINANCE  1000000.0
#
#   joining_date  is_active
# 0   2026-09-16       True
# 1   2025-11-20      False
# 2   2024-06-10      False
# 3   2026-09-26       True
# 4   2026-07-16       True

# %%
pwd
# Out:
# 'C:\\Users\\dell\\OneDrive\\Desktop\\API_Project'

# %%
pwd
# Out:
# 'C:\\Users\\dell\\OneDrive\\Desktop\\API_Project'

# %%
import panda as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 import panda as pd
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd

# %%
import os

# %%
path = os.path.join("data", "employees.csv")

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#   employee_id         name              email department     salary  \
# 0      EMP001       string   user@example.com     string        1.0
# 1      EMP002  Priya Singh  priya@example.com         HR    65000.0
# 2      EMP003   Amit Kumar   amit@example.com    Finance    55000.0
# 3     aarav08        aarav      arv@gmail.com         HR  1000000.0
# 4      EMP007       aaRAV2    ttt@example.com    FINANCE  1000000.0
#
#   joining_date  is_active
# 0   2026-09-16       True
# 1   2025-11-20      False
# 2   2024-06-10      False
# 3   2026-09-26       True
# 4   2026-07-16       True

# %%
df =df.rename(columns={"employee_id":"NAME","email":"gmail"})
df.head()
# Out:
#       NAME         name              gmail department     salary joining_date  \
# 0   EMP001       string   user@example.com     string        1.0   2026-09-16
# 1   EMP002  Priya Singh  priya@example.com         HR    65000.0   2025-11-20
# 2   EMP003   Amit Kumar   amit@example.com    Finance    55000.0   2024-06-10
# 3  aarav08        aarav      arv@gmail.com         HR  1000000.0   2026-09-26
# 4   EMP007       aaRAV2    ttt@example.com    FINANCE  1000000.0   2026-07-16
#
#    is_active
# 0       True
# 1      False
# 2      False
# 3       True
# 4       True

# %%
df.query
